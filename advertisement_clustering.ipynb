# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib as plt

# %%
# 광고 공공데이터 불러오기
data_광고소재명별광고정보 = pd.read_csv('./data/advertisement/한국방송광고진흥공사_AISAC 광고소재명별 광고 정보_20240731.csv', encoding='utf-8-sig')
data_AI인식광고소재명키워드 = pd.read_csv('./data/advertisement/한국방송광고진흥공사_AiSAC시스템 AI 인식결과 및 광고소재명별 키워드_20240731.csv', encoding='utf-8-sig')

# 광고타겟 공공데이터 불러오기

# %%
# print(data_광고소재명별광고정보[:5])
# 대업종 분류별 광고 개수
data_광고소재명별광고정보['대업종 분류'].value_counts().plot(kind='bar', figsize=(15, 5), title='대업종 분류별 광고 개수')
plt.rc('font', family='Malgun Gothic')
plt.pyplot.show()
# 대업종

# %%
data_광고소재명별광고정보.isnull().sum()  # 결측치 확인
# Out:
# 광고소재명         0
# 광고소재등록일       0
# 광고소재초수        2
# 대업종 분류        0
# 중업종 분류        0
# 소업종 분류        0
# 광고주명        283
# 광고회사명      2264
# 광고제작사      2895
# dtype: int64
